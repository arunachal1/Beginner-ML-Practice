# %%
import numpy as np
import pandas as pd

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
movies = pd.read_csv('http://bit.ly/imdbratings')
orders = pd.read_csv('http://bit.ly/chiporders', sep='\t')
orders['item_price'].str.replace('$', '').astype('float')
stocks = pd.read_csv('http://bit.ly/smallstocks', parse_dates=['Date'])
titanic = pd.read_csv('http://bit.ly/kaggletrain')
ufo = pd.read_csv('http://bit.ly/uforeports', parse_dates=['Time'])
# Out:
# /tmp/ipykernel_17766/886433236.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders['item_price'].str.replace('$', '').astype('float')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.loc[:, ::-1]
# Out:
#          continent  total_litres_of_pure_alcohol  wine_servings  \
# 0             Asia                           0.0              0
# 1           Europe                           4.9             54
# 2           Africa                           0.7             14
# 3           Europe                          12.4            312
# 4           Africa                           5.9             45
# ..             ...                           ...            ...
# 188  South America                           7.7              3
# 189           Asia                           2.0              1
# 190           Asia                           0.1              0
# 191         Africa                           2.5              4
# 192         Africa                           4.7              4
#
#      spirit_servings  beer_servings      country
# 0                  0              0  Afghanistan
# 1                132             89      Albania
# ...

# %%
drinks[::-1].reset_index(drop=True)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0       Zimbabwe             64               18              4
# 1         Zambia             32               19              4
# 2          Yemen              6                0              0
# 3        Vietnam            111                2              1
# 4      Venezuela            333              100              3
# ..           ...            ...              ...            ...
# 188       Angola            217               57             45
# 189      Andorra            245              138            312
# 190      Algeria             25                0             14
# 191      Albania             89              132             54
# 192  Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol      continent
# 0                             4.7         Africa
# 1                             2.5         Africa
# ...

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.select_dtypes(exclude='number')
# Out:
#          country      continent
# 0    Afghanistan           Asia
# 1        Albania         Europe
# 2        Algeria         Africa
# 3        Andorra         Europe
# 4         Angola         Africa
# ..           ...            ...
# 188    Venezuela  South America
# 189      Vietnam           Asia
# 190        Yemen           Asia
# 191       Zambia         Africa
# 192     Zimbabwe         Africa
#
# [193 rows x 2 columns]

# %%
data = pd.DataFrame({'col 1': ['100', '200'], 'col 2': ['200', '300']})

# %%
data
# Out:
#   col 1 col 2
# 0   100   200
# 1   200   300

# %%
data.astype({'col 1': float, 'col 2': float})
# Out:
#    col 1  col 2
# 0  100.0  200.0
# 1  200.0  300.0

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-06-01 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-06-01 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
ufo.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo['Colors Reported'].value_counts()
# Out:
# RED                       780
# GREEN                     531
# ORANGE                    528
# BLUE                      450
# YELLOW                    169
# RED GREEN                  89
# RED BLUE                   78
# RED ORANGE                 44
# GREEN BLUE                 34
# RED GREEN BLUE             33
# ORANGE YELLOW              26
# RED YELLOW                 25
# ORANGE GREEN               23
# YELLOW GREEN               17
# ORANGE BLUE                10
# RED YELLOW GREEN            9
# YELLOW BLUE                 6
# YELLOW GREEN BLUE           5
# ORANGE GREEN BLUE           5
# RED YELLOW GREEN BLUE       4
# RED ORANGE YELLOW           4
# RED YELLOW BLUE             3
# RED ORANGE GREEN            3
# RED ORANGE BLUE             3
# RED ORANGE YELLOW BLUE      1
# ORANGE YELLOW GREEN         1
# ORANGE YELLOW BLUE          1
# Name: Colors Reported, dtype: int64
